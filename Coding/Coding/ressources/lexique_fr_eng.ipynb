# %% [markdown]
# ***AUTHOR : Manel Djehiche SII M2 promo 2019/2020 usthb***
#
# ***gmail  : maneldje81@gmail.com***

# %% [markdown]
# `ce fichier contient le script de construction des deux dictionnaires : français et anglais que nous avons utilisés pour la détection de la langue.`

# %%
#load librarys
import numpy as np
import pandas as pd
import nltk
from nltk import re
from nltk import defaultdict
import io
from nltk import  word_tokenize
from nltk import  sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import codecs
import csv
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#sauvgarder un fichier pickle
def save_pickle(variable,filename):
    with open(filename, 'wb') as handle:
         pickle.dump(variable, handle, protocol=pickle.HIGHEST_PROTOCOL)

#ouvrire un fichier csv       
def open_csv(path):
      dataset=pd.read_csv(path,error_bad_lines=False,encoding='utf8')
      return dataset
     
#vérifie si l'encodage est utf_8
def check_utf8(filename): 
        try:
            f = codecs.open(filename, encoding='utf-8', errors='strict')
            for line in f:
                pass
            return 1 #valid utf_8
        except UnicodeDecodeError:
            return 0 #invalid utf_8

# ouvrir un fichier text
def open_txt_file(chemin):
    #open text file atfter checking if its utf_8  encoding    
    check=check_utf8(chemin)
    if(check == 1):
        f = io.open(chemin,'r',encoding='utf8')
    elif(check == 0):
        f = io.open(chemin,'r')
    return f.read()
    
# convertir fichier text vers une liste
def text_to_list(chemin):
    text=open_txt_file(chemin)
    liste=[]
    liste=text.split("\n")
    return liste

# %% [markdown]
# **Dictionnaire francais**

# %% [markdown]
# `charger le dictionnaire français`

# %%
path=r"/content/drive/My Drive/PROJET FIN ETUDE 2019 2020/ressources/lexique/lexique383_reduit.csv"
result=open_csv(path)

# %%
#construire liste mot des deux colonne de lexique
liste=[]
for x in result.columns:
    for word in result[x]:

        liste.append(word)

#supp les doublons
final_liste=set(liste)
print(len(final_liste))


#fonction qui verifi si un mot appartient 
def detect_fr(word,final_liste):
    if word in final_liste:
        return True
    else:
        return False

#enregistrer dans fichier text
file1 = open("/content/drive/My Drive/PROJET FIN ETUDE 2019 2020/ressources/lexique/lexique_fr.txt","w")
for word in final_liste:
    print(word)
    file1.writelines(str(word)+"\n") 
file1.close() #to change file access modes 

#save_pickle(final_liste,"/content/drive/My Drive/PROJET FIN ETUDE 2019 2020/lexique/lexique_fr.pickle")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# par-devant
# pleurite
# vinrent
# intensivement
# imposé
# descenseur
# fonceur
# supputent
# brai
# modestes
# entropiques
# entremit
# détricote
# dératisés
# rendormirait
# reverrions
# roulent
# piqûre
# divorcée
# empochent
# mi-courtois
# offriront
# constater
# cracheurs
# enfouillé
# sucée
# assenais
# tranchecaille
# relèvement
# apprendre
# déboulais
# mobilisent
# lactée
# réapparaîtrait
# bourgades
# informatisées
# pardi
# gravées
# caroubler
# cuvait
# finalistes
# égrillarde
# valses-hésitations
# turgotine
# télécommandées
# bachique
# bavassant
# promettrai
# dévisageons
# caressé
# boulimie
# placides
# cerclées
# marchiez
# risette
# exposons
# senteurs
# enzyme
# octroi
# perrier
# évaporaient
# conventuelle
# affectâmes
# rauques
# voyageras
# scribes
# confisquerons
# insulinique
# béaient
# achevait
# flave
# honneurs
# retreinte
# édouardien
# cailles
# divinations
# apparente
# ...

# %%
print(len(final_liste))
# Out:
# 128893

# %% [markdown]
# **Dicitonnaire anglais**

# %% [markdown]
# `charger le dictionnaire anglais.`

# %%
#enregistrer dans fichier text
chemin2="/content/drive/My Drive/PROJET FIN ETUDE 2019 2020/ressources/lexique/english3.txt"
final_liste2=text_to_list(chemin2)

# %%
final_liste2=list(set(final_liste2))
len(final_liste2)
# Out:
# 194434

# %%
final_liste2
# Out:
# ['saros',
#  'tiering',
#  '',
#  'bastinados',
#  'german',
#  'june',
#  'flagged',
#  'asparaguses',
#  'kanjis',
#  'totalise',
#  'boucle',
#  'stronghead',
#  'explanations',
#  'brimful',
#  'marchmen',
#  'outstanding',
#  'sources',
#  'boohooed',
#  'gauds',
#  'gilravage',
#  'proscribe',
#  'asphyxiant',
#  'brionies',
#  'wingman',
#  'ascesis',
#  'breeziest',
#  'gravitative',
#  'hornbeaks',
#  'laundry',
#  'multi',
#  'redcurrants',
#  'exhilarator',
#  'underbushing',
#  'exorbitate',
#  'whally',
#  'brownie',
#  'midrange',
#  'interwreathing',
#  'syndicalistic',
#  'vetiver',
#  'repaying',
#  'overgrain',
#  'vincristine',
#  'cardioid',
#  'africanizes',
#  'fother',
#  'doom',
#  'scott',
#  'thebans',
#  'bums',
#  'throbbed',
#  'borates',
#  'improper',
#  'residuary',
#  'overbound',
#  'piddles',
#  'unballasted',
#  'ballow',
#  'helcoid',
#  'personalist',
#  'breathalyzing',
#  'sorryish',
#  'protococcal',
#  'herbaries',
#  'alphabetizing',
# ...

# %%
len(final_liste2)
# Out:
# 194434

# %%
save_pickle(final_liste2,"/content/drive/My Drive/PROJET FIN ETUDE 2019 2020/ressources/lexique/lexique_eng.pickle")
